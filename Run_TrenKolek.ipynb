# %%
# !pip install streamlit pandas sqlalchemy

# %%
import streamlit as st

# %%
# !jupyter nbconvert --to script Streamlit_Tren_Kolektibilitas.ipynb
# !streamlit run Streamlit_Tren_Kolektibilitas.py
# Out:
# [NbConvertApp] Converting notebook Streamlit_Tren_Kolektibilitas.ipynb to script
# [NbConvertApp] Writing 6074 bytes to Streamlit_Tren_Kolektibilitas.py
# ^C

# %%
# !jupyter nbconvert --to script V2_Streamlit_Tren_Kolektibilitas.ipynb
# !streamlit run V2_Streamlit_Tren_Kolektibilitas.py
# Out:
# [NbConvertApp] Converting notebook V2_Streamlit_Tren_Kolektibilitas.ipynb to script
# [NbConvertApp] Writing 23861 bytes to V2_Streamlit_Tren_Kolektibilitas.py
